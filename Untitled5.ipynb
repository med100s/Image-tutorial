# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-f2f01901-4fbf-478a-875b-1cd4c97fcad9" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-f2f01901-4fbf-478a-875b-1cd4c97fcad9">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving b95990619a2f6b4d65043ec0aeb373b7.jpg to b95990619a2f6b4d65043ec0aeb373b7 (4).jpg

# %%
# !ls
# Out:
# '1000015157 (1).jpg'			    'bee-on-daisy (1).jpg'
#  1000015157.jpg				    'bee-on-daisy (2).jpg'
# 'b95990619a2f6b4d65043ec0aeb373b7 (1).jpg'  'bee-on-daisy (3).jpg'
# 'b95990619a2f6b4d65043ec0aeb373b7 (2).jpg'   bee-on-daisy.jpg
# 'b95990619a2f6b4d65043ec0aeb373b7 (3).jpg'   sample_data
# 'b95990619a2f6b4d65043ec0aeb373b7 (4).jpg'   yubQ4jgInGY.jpg
#  b95990619a2f6b4d65043ec0aeb373b7.jpg

# %%
keys = list(uploaded.keys())

keys[0]
# Out:
# 'b95990619a2f6b4d65043ec0aeb373b7.jpg'

# %%
print(keys[0])
# Out:
# b95990619a2f6b4d65043ec0aeb373b7.jpg

# %%
img = mpimg.imread(keys[0])

# %%
imgplot = plt.imshow(img)

# %%
lum_img = img[:, :, 0]

# This is array slicing.  You can read more in the `Numpy tutorial
# <https://docs.scipy.org/doc/numpy/user/quickstart.html>`_.

plt.imshow(lum_img)

# %%
plt.imshow(lum_img, cmap="hot")

# %%
imgplot = plt.imshow(lum_img)
imgplot.set_cmap('nipy_spectral')

# %%
imgplot = plt.imshow(lum_img)
plt.colorbar()

# %%
imgplot = plt.imshow(lum_img, clim=(130,170))

# %%
from PIL import Image

imp = Image.open(keys[0])
imp.thumbnail((64, 64), Image.ANTIALIAS)  # resizes image in-place
imgplot = plt.imshow(imp)

# %%
imgplot = plt.imshow(imp, interpolation="bicubic")
